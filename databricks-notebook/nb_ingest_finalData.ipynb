# %%
spark.conf.set(
  "fs.azure.account.auth.type.suryanshetlproject.dfs.core.windows.net",
  "OAuth"
)

spark.conf.set(
  "fs.azure.account.oauth.provider.type.suryanshetlproject.dfs.core.windows.net",
  "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider"
)

spark.conf.set(
  "fs.azure.account.oauth2.client.id.suryanshetlproject.dfs.core.windows.net",
  "17474544-8fc1-44fb-a472-59eb6cde6418"
)

spark.conf.set(
  "fs.azure.account.oauth2.client.secret.suryanshetlproject.dfs.core.windows.net",
  "dUg8Q~deXPrpDNiBP4b2YwgbkII94LHlPmQLuaoy"
)

spark.conf.set(
  "fs.azure.account.oauth2.client.endpoint.suryanshetlproject.dfs.core.windows.net",
  "https://login.microsoftonline.com/0887fcaa-8c9f-45e8-9880-41333202ebee/oauth2/token"
)

# %%
# %sql
USE CATALOG adb_adventureworks_etl;

# %%
# %sql
select current_catalog();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_catalog()</th></tr></thead><tbody><tr><td>adb_adventureworks_etl</td></tr></tbody></table></div>

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS adventureworks_transformed;

# %%
df = spark.read.parquet("abfss://etl-project@suryanshetlproject.dfs.core.windows.net/target_parquet/CustomerOrders.parquet")

df.write.mode("overwrite").saveAsTable(
    "adb_adventureworks_etl.adventureworks_transformed.customer_orders"
)

# %%
df = spark.read.parquet("abfss://etl-project@suryanshetlproject.dfs.core.windows.net/target_parquet/HighMarginProducts.parquet")

df.write.mode("overwrite").saveAsTable(
    "adb_adventureworks_etl.adventureworks_transformed.high_margin_products"
)

# %%
df = spark.read.parquet("abfss://etl-project@suryanshetlproject.dfs.core.windows.net/target_parquet/LowMarginProducts.parquet")

df.write.mode("overwrite").saveAsTable(
    "adb_adventureworks_etl.adventureworks_transformed.low_margin_products"
)

# %%
df = spark.read.parquet("abfss://etl-project@suryanshetlproject.dfs.core.windows.net/target_parquet/MediumMarginProducts.parquet")

df.write.mode("overwrite").saveAsTable(
    "adb_adventureworks_etl.adventureworks_transformed.medium_margin_products"
)

# %%
df = spark.read.parquet("abfss://etl-project@suryanshetlproject.dfs.core.windows.net/target_parquet/OrderDetailsExt.parquet")

df.write.mode("overwrite").saveAsTable(
    "adb_adventureworks_etl.adventureworks_transformed.order_details_ext"
)

# %%
df = spark.read.parquet("abfss://etl-project@suryanshetlproject.dfs.core.windows.net/target_parquet/OrderTotal.parquet")

df.write.mode("overwrite").saveAsTable(
    "adb_adventureworks_etl.adventureworks_transformed.order_total"
)

# %%
df = spark.read.parquet("abfss://etl-project@suryanshetlproject.dfs.core.windows.net/target_parquet/ProductPerformance.parquet")

df.write.mode("overwrite").saveAsTable(
    "adb_adventureworks_etl.adventureworks_transformed.product_performance"
)

# %%
df = spark.read.parquet("abfss://etl-project@suryanshetlproject.dfs.core.windows.net/target_parquet/SalesPersonRanked.parquet")

df.write.mode("overwrite").saveAsTable(
    "adb_adventureworks_etl.adventureworks_transformed.sales_person_ranked"
)

# %%
# %sql
SHOW TABLES IN adventureworks_transformed;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
